# %% [markdown]
# <a href="https://colab.research.google.com/github/abkdata/data_science_for_everyone/blob/main/ABK-SparkTest3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark py4j #Installation
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285387 sha256=4a546d23a6265a2b6008ea82293d845528316978257b87af0cd19e4aff12ee66
#   Stored in directory: /root/.cache/pip/wheels/0d/77/a3/ff2f74cc9ab41f8f594dabf0579c2a7c6de920d584206e0834
# Successfully built pyspark
# ...

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Abk to test pyspark App").getOrCreate()

# %%
df = spark.read.csv("/content/sample_data/california_housing_test.csv", header=True, inferSchema=True)

# %%
df.show(2)
# Out:
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+
# |longitude|latitude|housing_median_age|total_rooms|total_bedrooms|population|households|median_income|median_house_value|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+
# |  -122.05|   37.37|              27.0|     3885.0|         661.0|    1537.0|     606.0|       6.6085|          344700.0|
# |   -118.3|   34.26|              43.0|     1510.0|         310.0|     809.0|     277.0|        3.599|          176500.0|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+
# only showing top 2 rows

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.printSchema()
# Out:
# root
#  |-- longitude: double (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- housing_median_age: double (nullable = true)
#  |-- total_rooms: double (nullable = true)
#  |-- total_bedrooms: double (nullable = true)
#  |-- population: double (nullable = true)
#  |-- households: double (nullable = true)
#  |-- median_income: double (nullable = true)
#  |-- median_house_value: double (nullable = true)

# %%
df.describe().toPandas().T
# Out:
#                         0                    1                   2        3  \
# summary             count                 mean              stddev      min
# longitude            3000  -119.58920000000029  1.9949362939550166  -124.18
# latitude             3000    35.63538999999999  2.1296695233438334    32.56
# housing_median_age   3000   28.845333333333333  12.555395554955757      1.0
# total_rooms          3000    2599.578666666667   2155.593331625582      6.0
# total_bedrooms       3000    529.9506666666666  415.65436813632306      2.0
# population           3000   1402.7986666666666  1030.5430124122424      5.0
# households           3000              489.912  365.42270980552615      2.0
# median_income        3000    3.807271799999998  1.8545117296914775   0.4999
# median_house_value   3000           205846.275  113119.68746964622  22500.0
#
#                            4
# summary                  max
# longitude            -114.49
# latitude               41.92
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(25, 15))
st = fig.suptitle("Distribution of Features", fontsize=50, verticalalignment="center")

for col, num in zip(df.toPandas().describe().columns, range(1,11)):
  ax = fig.add_subplot(3, 4, num)
  ax.hist(df.toPandas()[col])
  plt.grid(False)
  plt.xticks(rotation=45, fontsize=20)
  plt.yticks(fontsize=15)
  plt.title(col.upper(), fontsize=20)

plt.tight_layout()
st.set_y(0.95)
fig.subplots_adjust(top=0.85, hspace=0.4)
plt.show()

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b666bf274d0a> in <cell line: 1>()
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(25, 15))
st = fig.suptitle("Distribution of Features", fontsize=50, verticalalignment="center")

for col, num in zip(df.toPandas().describe().columns, range(1,11)):
  ax = fig.add_subplot(3, 4, num)
  ax.hist(df.toPandas()[col])
  plt.grid(False)
  plt.xticks(rotation=45, fontsize=20)
  plt.yticks(fontsize=15)
  plt.title(col.upper(), fontsize=20)

plt.tight_layout()
st.set_y(0.95)
fig.subplots_adjust(top=0.85, hspace=0.4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-19527ebc0212> in <cell line: 4>()
#       2 st = fig.suptitle("Distribution of Features", fontsize=50, verticalalignment="center")
#       3
# ----> 4 for col, num in zip(df.toPandas().describe().columns, range(1,11)):
#       5   ax = fig.add_subplot(3, 4, num)
#       6   ax.hist(df.toPandas()[col])
#
# NameError: name 'df' is not defined

# %%
sector_df.plot(kind="population", x="households",y=sector_df.columns.tolist()[1:], figsize=(12, 12));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-7cd2f027893b> in <cell line: 1>()
# ----> 1 sector_df.plot(kind="population", x="households",y=sector_df.columns.tolist()[1:], figsize=(12, 12));
#
# NameError: name 'sector_df' is not defined
